# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns
df=pd.read_csv('Chicago_Crimes_2012_to_2017.csv',index_col='Date')

# %% [markdown]
# # LETS INVESTIGATE AND ANALYSE CHICAGO CRIME DATASET

# %%
df.head()
# Out:
#                         Unnamed: 0        ID Case Number                Block  \
# Date
# 05/03/2016 11:40:00 PM           3  10508693    HZ250496   013XX S SAWYER AVE
# 05/03/2016 09:40:00 PM          89  10508695    HZ250409   061XX S DREXEL AVE
# 05/03/2016 11:31:00 PM         197  10508697    HZ250503  053XX W CHICAGO AVE
# 05/03/2016 10:10:00 PM         673  10508698    HZ250424    049XX W FULTON ST
# 05/03/2016 10:00:00 PM         911  10508699    HZ250455    003XX N LOTUS AVE
#
#                         IUCR            Primary Type              Description  \
# Date
# 05/03/2016 11:40:00 PM  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 05/03/2016 09:40:00 PM  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 05/03/2016 11:31:00 PM  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 05/03/2016 10:10:00 PM  0460                 BATTERY                   SIMPLE
# 05/03/2016 10:00:00 PM  0820                   THEFT           $500 AND UNDER
#
# ...

# %% [markdown]
# * since attributes such as unnamed,id and case number doesnt bring much sence,we need to get rid of these attributes

# %%
df=df.iloc[:,3:]

# %%
df.head()
# Out:
#                                       Block  IUCR            Primary Type  \
# Date
# 05/03/2016 11:40:00 PM   013XX S SAWYER AVE  0486                 BATTERY
# 05/03/2016 09:40:00 PM   061XX S DREXEL AVE  0486                 BATTERY
# 05/03/2016 11:31:00 PM  053XX W CHICAGO AVE  0470  PUBLIC PEACE VIOLATION
# 05/03/2016 10:10:00 PM    049XX W FULTON ST  0460                 BATTERY
# 05/03/2016 10:00:00 PM    003XX N LOTUS AVE  0820                   THEFT
#
#                                     Description Location Description  Arrest  \
# Date
# 05/03/2016 11:40:00 PM  DOMESTIC BATTERY SIMPLE            APARTMENT    True
# 05/03/2016 09:40:00 PM  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 05/03/2016 11:31:00 PM         RECKLESS CONDUCT               STREET   False
# 05/03/2016 10:10:00 PM                   SIMPLE             SIDEWALK   False
# 05/03/2016 10:00:00 PM           $500 AND UNDER            RESIDENCE   False
#
# ...

# %%
df.groupby('Primary Type').size().sort_values(ascending=False)[:5].plot('barh')

# %% [markdown]
# * THE MAJOR CAUSE OF CRIMES NOTICED ARE----->THEFT,BATTERY,CRIMINAL DAMAGE,NARCOTICS and ASSAULT
# * The LEAST TYPES  OF CRIMES ARE------->NON CRIMINAL,HUMAN TRAFFICKING AND PUBLIC INDECENCY

# %%
df.groupby('Location Description').size().sort_values(ascending=False)[:8].plot('barh')

# %%
df.groupby('Location Description').size().sort_values(ascending=True)[:5].plot('barh')

# %% [markdown]
# * MOST OF THE CRIMES HAPPEND AT STREET,RESIDENCE,APARTMENT,SIDEWLAK AND PARKING LOT LOCATIONS
#   AND LEAST AT LAUNDRY ROOM,CLUB,ELEVATOR AND CHURCH PROPERTY

# %%
x=df['Arrest'].value_counts()
sns.barplot(x=x.index,y=x)

# %%
pd.crosstab(df['Arrest'],df['Primary Type'])
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Arrest
# False          1999    69941   203199     78934
# True            218    21348    60501      4463
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Arrest
# False                                        13                 6014
# True                                         77                  809
#
# Primary Type  CRIMINAL DAMAGE  CRIMINAL TRESPASS  DECEPTIVE PRACTICE  \
# Arrest
# False                  145290              10985               66578
# True                    10165              25927                8917
#
# Primary Type  GAMBLING        ...          OTHER NARCOTIC VIOLATION  \
# Arrest                        ...
# False                7        ...                                 9
# True              2205        ...                                21
#
# Primary Type  OTHER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  \
# Arrest
# ...

# %%
df[df['Arrest']==True]['Primary Type'].value_counts().sort_values(ascending=False)[:8].plot('barh')

# %%
df[df['Arrest']==False]['Primary Type'].value_counts().sort_values(ascending=False)[:8].plot('barh')

# %% [markdown]
# -->ONLY 3 LAKH PEOPLE WERE ARRESTED AND NEARLY ABOVE 10 LAKH PEOPLE WERE SET FREE
# -->MOSTLY THE PEOPLE WHO COMMITTED NARCOTICS,BATTERY,THEFT WERE ARRESTED AND PEOPLE SUBJECTED TO THEFT,BATTERY AND CRIMINAL-DAMAGE
# WERE ALSO SET FREE IN LARGE SCALE

# %%
x=df['Year'].value_counts()
sns.barplot(x=x.index,y=x)

# %% [markdown]
# YEAR 2012 HAS WITNESSED MORE CRIMES AND 2017 HAS WITNESSED ALMOST NEGLIGIBLE CRIMES
# YEARS 2014-15-16 ARE TARGETED TO EQUAL AMOUNT OF CRIMES

# %%
crime2012=df[df.index.str.find('2012')!=-1][:]

# %%
crime2012
# Out:
#                                                       Block  IUCR  \
# Date
# 01/01/2012 12:00:00 AM                026XX N MC VICKER AVE  1562
# 01/01/2012 12:00:00 AM                026XX N MC VICKER AVE  1544
# 04/13/2012 12:00:00 AM  064XX S DR MARTIN LUTHER KING JR DR  1154
# 08/12/2012 12:00:00 PM               027XX S CHRISTIANA AVE  1563
# 02/13/2012 07:00:00 PM                  070XX S WESTERN AVE  1130
# 06/01/2012 12:00:00 PM              017XX N SPRINGFIELD AVE  0281
# 11/01/2012 09:00:00 AM                   073XX N HARLEM AVE  1153
# 07/09/2012 09:00:00 AM                  071XX S SANGAMON ST  1153
# 05/28/2012 09:00:00 AM                      009XX E 84TH ST  1120
# 07/14/2012 03:00:00 PM                   041XX N MENARD AVE  1750
# 08/08/2012 05:30:00 PM                   029XX S POPLAR AVE  0810
# 10/05/2012 05:00:00 PM                 042XX N LOCKWOOD AVE  0486
# 10/23/2012 04:00:00 AM                039XX N CLARENDON AVE  0486
# ...

# %%
x=crime2012['Primary Type'].value_counts().sort_values(ascending=False)[:5]

# %%
def func(i):
    l=[]
    for j in ['01','02','03','04','05','06','07','08','09','10','11','12']:
        l.append(crime2012[(crime2012['Primary Type']==x.index[i]) & (crime2012.index.str[0:2]==j)]['Primary Type'].count())
    return(l,x.index[i])

# %%
for i in range(5):
    m=np.arange(1,13,1)
    l,t=func(i)
    plt.plot(m,l,label=t)
plt.xlabel('months')
plt.ylabel('crimes')
plt.title('TOP 5 CRIMES IN CHICAGO IN 2012')
plt.xticks(m,['jan','feb','mar','apr','may','june','july','aug','sep','oct','nov','dec'])
plt.legend(bbox_to_anchor=(1,0.5))

# %% [markdown]
# * THEFTS ARE USUALLY HIGH DURING MONTHS OF JULY AND AUGUST
# * CRIMINAL DAMAGES,ASSUALT AND BURGLARY ARE USUALLY LEAST IN FEBRUARY
# * ALL TYPES OF CRIMES WERE HIGH IN MONTH OF JULY

# %%
crime2013=df[df.index.str.find('2013')!=-1][:]
x=crime2013['Primary Type'].value_counts().sort_values(ascending=False)[:5]

# %%
def func(i):
    l=[]
    for j in ['01','02','03','04','05','06','07','08','09','10','11','12']:
        l.append(crime2013[(crime2013['Primary Type']==x.index[i]) & (crime2013.index.str[0:2]==j)]['Primary Type'].count())
    return(l,x.index[i])

# %%
for i in range(5):
    m=np.arange(1,13,1)
    l,t=func(i)
    plt.plot(m,l,label=t)
plt.xlabel('months')
plt.ylabel('crimes')
plt.title('TOP 5 CRIMES IN CHICAGO IN 2013')
plt.xticks(m,['jan','feb','mar','apr','may','june','july','aug','sep','oct','nov','dec'])
plt.legend(bbox_to_anchor=(1,0.5))

# %% [markdown]
# * IN 2013, CRIME RATE IS LEAST IN FEBRUARY AND DECEMBER
# * IN MID OF AUGUST AND SEPTEMBER CRIME RATE IS TOO HIGH
